# %%
myname='ramakrishna'

# %%
print('hello'+  myname)
# Out:
# helloramakrishna

# %%
print('string 1{}'.format('insert'))
# Out:
# string 1insert

# %%
print('string {1} {1} {1}'.format('black','brown','red'))
# Out:
# string brown brown brown

# %%
print('string {c} {a} {a}'.format(a='black',b='brown',c='red'))
# Out:
# string red black black

# %%
'print formatting follows"{value:width.precision f}"'
# Out:
# 'print formatting follows"{value:width.precision f}"'

# %%
result =1000/777

# %%
result
# Out:
# 1.287001287001287

# %%
print("the result is{r:100000.5f}".format(r=result))
# Out:
# the result is                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# ...

# %%
result1=5*22.75

# %%
print("the result is{r:100000.5f}".format(r=result1))
# Out:
# the result is                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# ...

# %%
name='roy'

# %%
print('his name is {}'.format(name))
# Out:
# his name is roy

# %%
print(f'his name is {name}')
# Out:
# his name is roy

# %%
name="kaustub"
age= 1.8

# %%
print(f'{name} is {age} years old ')
# Out:
# kaustub is 1.8 years old
