# %% [markdown]
# # "MILESTONE PROJECT 1 TIC TAC TOE"

# %%
from IPython.display import clear_output
clear_output()

# %%
def display_board(board):
    print('    |   |')
    print('  '+board[7]+' | '+board[8]+' | '+board[9])
    print('    |   |')
    print(' ----------')
    print('    |   |')
    print('  '+board[4]+' | '+board[5]+' | '+board[6])
    print('    |   |')
    print(' ----------')
    print('    |   |')
    print('  '+board[1]+' | '+board[2]+' | '+board[3])

# %%
test_board=['#','X','O','X','O','X','O','X','O','X']
display_board(test_board)
# Out:
#     |   |
#   X | O | X
#     |   |
#  ----------
#     |   |
#   O | X | O
#     |   |
#  ----------
#     |   |
#   X | O | X

# %%
def player_input():
    marker=''
    #asking player is choose X or O
    while (marker!='X'and marker!='O'):
        
        marker=input("player 1,Choose X or O: ").upper()
        
        #Assign Player 2 opposite marker
        
        
        if marker=='X':
            
            return ('X','O')
        else:
            
            return ('O','X')

# %%
player_input()
# Out:
# player 1,Choose X or O: x
# ('X', 'O')

# %%
def place_marker(board, marker, position):
    
    board[position]=marker

# %%
place_marker(test_board,'$',8)
display_board(test_board)
# Out:
#     |   |
#   X | $ | X
#     |   |
#  ----------
#     |   |
#   O | X | O
#     |   |
#  ----------
#     |   |
#   X | O | X

# %%
def win_check(board, mark):
    
    return ((board[7] == mark and board[8] == mark and board[9] == mark or
             board[4] == mark and board[5] == mark and board[6] == mark or
             board[1] == mark and board[2] == mark and board[3] == mark or
             board[7] == mark and board[4] == mark and board[1] == mark or
             board[8] == mark and board[5] == mark and board[2] == mark or
             board[9] == mark and board[6] == mark and board[3] == mark or
             board[7] == mark and board[5] == mark and board[3] == mark or
             board[9] == mark and board[5] == mark and board[1] == mark))

# %%
win_check(test_board,'X')
# Out:
# True

# %%
import random

def choose_first():
    if random.randint(0,1)==0:
        return 'player2'
    else:
        return 'player1'

# %%
choose_first()
# Out:
# 'player2'

# %%
def space_check(board, position):
    return board[position]==' '

# %%
def full_board_check(board):
    for i in range(1,10):
        
        if space_check(board,i):
            return False
    return True

# %%
full_board_check(test_board)
# Out:
# True

# %%
def player_choice(board):
    position=0
    
    while position not in [1,2,3,4,5,6,7,8,9] or not space_check(board,position):
        
        position=int(input("Choose your next position in (1-9): "))
        
    return position

# %%
def replay():
    
    return input("Do you want to play again,Enter Yes or No: ").lower().startswith('y')

# %%
replay()
# Out:
# Do you want to play again,Enter Yes or No: y
# True

# %%
print("WELCOME TO TIC TAC TOE")

while True:
    theboard=[' ']*10
    player1_marker,player2_marker=player_input()
    display_board(theboard)
    
    turn=choose_first()
    
    print(turn+" will go first")
    
    play_game=input("Are you ready to play or not: ")
    
    if play_game.lower()[0] == 'y':
        game_on = True
    else:
        game_on = False
        
    while game_on:
            
        if turn == 'player1':
                
            display_board(theboard)
            position=player_choice(theboard)
            place_marker(theboard,player1_marker,position)
                
            if win_check(theboard,player1_marker):
                display_board(theboard)
                print("Congratulations,you have won the game,Player1")
                game_on=False
                    
            else:
                    
                if full_board_check(theboard):
                        
                    display_board(theboard)
                        
                    print("The game is draw!")
                        
                    break
                else:
                    turn='player2'
                        
                        
        else:
                
            display_board(theboard)
            position=player_choice(theboard
                                  )
            place_marker(theboard,player2_marker,position)
                
            if win_check(theboard,player2_marker):
                display_board(theboard)
                print("Congratulations Player2 wins")
                game_on=False
            else:
                if full_board_check(theboard):
                        
                    display_board(theboard)
                    print("The game is draw!")
                    break
                else:
                    turn='player1'
                    
    if not replay():
        break
# Out:
# WELCOME TO TIC TAC TOE
# player 1,Choose X or O: x
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
# player1 will go first
# Are you ready to play or not: y
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
# Choose your next position in (1-9): 1
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#   X |   |
# Choose your next position in (1-9): 3
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#   X |   | O
# Choose your next position in (1-9): 2
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#   X | X | O
# Choose your next position in (1-9): 4
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#   O |   |
#     |   |
#  ----------
#     |   |
#   X | X | O
# Choose your next position in (1-9): 6
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#   O |   | X
#     |   |
#  ----------
#     |   |
#   X | X | O
# Choose your next position in (1-9): 8
#     |   |
#     | O |
#     |   |
#  ----------
#     |   |
#   O |   | X
#     |   |
#  ----------
#     |   |
#   X | X | O
# Choose your next position in (1-9): 5
#     |   |
#     | O |
#     |   |
#  ----------
#     |   |
#   O | X | X
#     |   |
#  ----------
#     |   |
#   X | X | O
# Choose your next position in (1-9): 7
#     |   |
#   O | O |
#     |   |
#  ----------
#     |   |
#   O | X | X
#     |   |
#  ----------
#     |   |
#   X | X | O
# Choose your next position in (1-9): 9
#     |   |
#   O | O | X
#     |   |
#  ----------
#     |   |
#   O | X | X
#     |   |
#  ----------
#     |   |
#   X | X | O
# Congratulations,you have won the game,Player1
# Do you want to play again,Enter Yes or No: y
# player 1,Choose X or O: o
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
# player2 will go first
# Are you ready to play or not: y
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
# Choose your next position in (1-9): 2
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 4
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#   O |   |
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 6
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#   O |   | X
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 8
#     |   |
#     | O |
#     |   |
#  ----------
#     |   |
#   O |   | X
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 9
#     |   |
#     | O | X
#     |   |
#  ----------
#     |   |
#   O |   | X
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 3
#     |   |
#     | O | X
#     |   |
#  ----------
#     |   |
#   O |   | X
#     |   |
#  ----------
#     |   |
#     | X | O
# Choose your next position in (1-9): 1
#     |   |
#     | O | X
#     |   |
#  ----------
#     |   |
#   O |   | X
#     |   |
#  ----------
#     |   |
#   X | X | O
# Choose your next position in (1-9): 5
#     |   |
#     | O | X
#     |   |
#  ----------
#     |   |
#   O | O | X
#     |   |
#  ----------
#     |   |
#   X | X | O
# Choose your next position in (1-9): 7
#     |   |
#   X | O | X
#     |   |
#  ----------
#     |   |
#   O | O | X
#     |   |
#  ----------
#     |   |
#   X | X | O
# The game is draw!
# Do you want to play again,Enter Yes or No: y
# player 1,Choose X or O: o
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
# player2 will go first
# Are you ready to play or not: y
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
# Choose your next position in (1-9): 8
#     |   |
#     | X |
#     |   |
#  ----------
#     |   |
#     |   |
#     |   |
#  ----------
#     |   |
#     |   |
# Choose your next position in (1-9): 4
#     |   |
#     | X |
#     |   |
#  ----------
#     |   |
#   O |   |
#     |   |
#  ----------
#     |   |
#     |   |
# Choose your next position in (1-9): 2
#     |   |
#     | X |
#     |   |
#  ----------
#     |   |
#   O |   |
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 6
#     |   |
#     | X |
#     |   |
#  ----------
#     |   |
#   O |   | O
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 7
#     |   |
#   X | X |
#     |   |
#  ----------
#     |   |
#   O |   | O
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 9
#     |   |
#   X | X | O
#     |   |
#  ----------
#     |   |
#   O |   | O
#     |   |
#  ----------
#     |   |
#     | X |
# Choose your next position in (1-9): 3
#     |   |
#   X | X | O
#     |   |
#  ----------
#     |   |
#   O |   | O
#     |   |
#  ----------
#     |   |
#     | X | X
# Choose your next position in (1-9): 5
#     |   |
#   X | X | O
#     |   |
#  ----------
#     |   |
#   O | O | O
#     |   |
#  ----------
#     |   |
#     | X | X
# Congratulations,you have won the game,Player1
